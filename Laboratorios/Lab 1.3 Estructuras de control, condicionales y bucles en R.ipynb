# %% [markdown]
# <a name = "inicio"></a>
#
# ***
#
# <div style="font-size: 30px;text-align: center;height:60px;padding:10px;margin:10px 0 0 0;">Laboratorio 1.3 Estructuras de control, condicionales y bucles en R </div>
#
# <table>
#   <tr>
#     <td>
# <div>
# <img src="attachment:image-2.png" width="135"/>
# <td>&nbsp;</td><td>&nbsp;</td>
# </div>
#     </td>
#     <td>
# <div>
# <img src="attachment:image-3.png" width="350"/>
# </div>
# </td>
#   </tr>
# <table>
#
# **Grupo No**:
#
# * *Nombre y apellidos miembro grupo 1*
# * *Nombre y apellidos miembro grupo 2*
# * *Nombre y apellidos miembro grupo 3*
#
# ***
#
# # Instrucciones de la prueba
#
# Este documento corresponde al **Laboratorio 1.3** que tenéis que realizar en grupo abarcando los conceptos vistos en el **Notebook 1.3**. Un alumno en representación del resto de compañeros deberá de entregar este mismo notebook con las respuestas a través de la plataforma **Blackboard** llamando al archivo **Lab1.3_Grupo#**. El profesor publicará la resolución de todos los ejercicios con posterioridad. ¡Mucha suerte y ánimo a tod@s!
#
# **<mark>Nota.-**<mark><div style="background-color:#F7DC6F"><b> Recordar que tenéis que completar cada uno de ellos incluyendo comentarios acerca de los resultados obtenidos describiendo con detalle cada una de las celdas tipo código paso a paso lo que estáis haciendo. Además, deberéis de incluir una celda tipo 'Markdown' al final de cada uno de los ejercicios realizando un resumen de los mismos. Os puede servir de ayuda consultar la documentación y recursos disponibles en la plataforma. </b></div>
#
# ***

# %% [markdown]
# ### Ejercicio 1
#
# Contestar a los siguientes apartados creando para ello vuestras propias funciones.
#
# 1. Dada una variable $x$, escribir una función que verifique si $x$ es par o impar.
# 2. Proponer una función que devuelva el producto de cuatro números.
# 3. Crear una función que, dado un vector y un número $n$, devuelva los primeros $n$ elementos del vector.
# 4. Desarrollar una función que invierta el orden de los elementos de un vector.
# 5. Escribir una función que sume todos los números en un vector hasta que encuentre un número negativo.

# %% [markdown]
# <div style="background-color:#F7DC6F"><b>Resolución Ejercicio 01</b></div>

# %% [markdown]
# <div style="background-color:#5DADE2"><b>Apartado 1</b></div>

# %% [markdown]
# ### Ejercicio 2
#
# Contestar a las siguientes cuestiones considerando para ello las funciones necesarias.
#
# 1. Utilizando un bucle $\tt for$, guardar los primeros 50 números en orden inverso, comenzando desde el $50$ y finalizando en $1$.
#
# 2. Haciendo uso de un bucle $\tt for$, imprimir únicamente los elementos que se encuentran en las posiciones pares del vector $\tt numerosPrimos = c(2,3,5,7,11,13,17,19)$.
#
# 3. Construir un bucle $\tt for$ con un total de 150 iteraciones. Partiendo de una cantidad inicial de $150€$, añadir $2€$ si el valor en la iteración actual es par, y sustraer $4€$ si dicho valor es impar.
#
# 4. Implementar un bucle $\tt while$ para mostrar los números pares que se encuentren entre $2$ y $10$.
#
# 5. Escribir un bucle $\tt while$ con el propósito de obtener de manera iterativa los primeros $500$ términos de la secuencia de Fibonacci, comenzando con los números $0$ y $1$.

# %% [markdown]
# <div style="background-color:#F7DC6F"><b>Resolución Ejercicio 02</b></div>

# %% [markdown]
# <div style="background-color:#5DADE2"><b>Apartado 1</b></div>

# %% [markdown]
# ### Ejercicio 3
#
# Contestar a los siguientes apartados utilizando las funciones oportunas.
#
# 1. Dado el vector $\tt nums = c(3, 5, 7)$, verificar si el primer elemento es menor que $10$. Si es cierto, imprimir "Menor que $10$".
# 2. Si el quinto elemento del vector $\tt values = c(10, 15, 20, 25, 30, 35)$ es igual a $30$, imprimir "El valor es $30$".
# 3. Dado el vector $\tt data = c(4, NA, 6, 7, NA, 10)$, verificar si contiene algún valor faltante (NA). Si es cierto, imprimir "Hay valores faltantes en el vector".
# 4. Dado un vector $\tt y = c(120, 24, 35, 24, 88, 120, 155, 88, 120, 155)$, verificar si el número más repetido aparece tres o más veces. Si es así, imprimir "Hay un número que se repite frecuentemente".

# %% [markdown]
# <div style="background-color:#F7DC6F"><b>Resolución Ejercicio 03</b></div>

# %% [markdown]
# <div style="background-color:#5DADE2"><b>Apartado 1</b></div>

# %% [markdown]
# ### Ejercicio 4
#
# Contestar a las siguientes cuestiones creando para ello vuestras propias funciones.
#
# 1. Realizar una función que reciba como parámetro un número y devuelva su valor absoluto.
#
# 2. Hacer una versión de la función $\tt sign$. Esta función recibe un vector numérico y devuelve un vector del mismo tamaño que el vector original, pero con los valores $1$ (valores positivos), $0$ (valores $0$) y $-1$ (valores negativos). Por ejemplo, $\tt sign(c(-4, 2, 0, 3))$ devuelve el vector $\tt c(-1, 1, 0, 1)$.
#
# 3. Escribir una función que dado un valor y un vector devuelva cuántas veces se encuentra el valor en el vector.
#
# 4. Plantear una función que, al recibir una matriz como entrada, reordene sus filas de manera inversa. Es decir, la fila inicial debe convertirse en la última, la segunda en la penúltima, y así consecutivamente.

# %% [markdown]
# <div style="background-color:#F7DC6F"><b>Resolución Ejercicio 04</b></div>

# %% [markdown]
# <div style="background-color:#5DADE2"><b>Apartado 1</b></div>

# %% [markdown]
# ### Ejercicio 5
#
# Contestar a las siguientes cuestiones utilizando para ello las funciones necesarias.
#
# 1. Escribir un bucle con $\tt while$ que imprima los números impares del $1$ al $19$.
#
# 2. Escribir un bucle con $\tt for$ para imprimir solo las posiciones impares del siguiente vector $\tt primos = c(2,2,1,2,3,5,6,7,11,12,13,17,19)$
#
# 3. Escribir un bucle con $\tt for$ para imprimir los $1000$ primeros números de manera ascendente. Es decir, comenzando desde el $1$ y terminando en $1000$.
#
# 4. Escribir un bucle con $\tt while$ para calcular de forma iterativa los $10000$ primeros elementos de la serie de Fibonacci: $0,1,1,2,3,5,8,13,...$

# %% [markdown]
# <div style="background-color:#F7DC6F"><b>Resolución Ejercicio 05</b></div>

# %% [markdown]
# <div style="background-color:#5DADE2"><b>Apartado 1</b></div>

# %% [markdown]
# ### Ejercicio 6
#
# Contestar a los siguientes apartados utilizando las funciones oportunas.
#
# 1. Contáis con una lista llamada $\tt lis$ con el siguiente formato. Verificar si la estudiante tiene más de $18$ años, su nombre tiene más de $4$ letras y su calificación promedio es mayor que $8$. Si todas las condiciones son ciertas, imprimir "La estudiante cumple con los criterios de admisión al nuevo grado".

# %%
lis = list(nombre = "Alicia", edad = 20, notas = c(7.8, 8.5, 9.0, 8.7))
lis

# %% [markdown]
# 2. Dado el dataframe $\tt df$ con las siguientes columnas: nombres, edades y salarios, comprobar si el salario promedio de las personas menores de 30 años es mayor que $\tt 50.000 euros$. Si es así, imprimir "Los jóvenes tienen sueldos por encima del salario medio nacional".

# %%
df <- data.frame(nombres = c("María", "Jorge", "Clara", "David"),
                 edades = c(25, 30, 28, 35),
                 salarios = c(52000, 48000, 53000, 55000))
df

# %% [markdown]
# 3. Dada la siguiente matriz $\tt mat$ de dimensiones $3x3$, verificar si la suma de los elementos de la diagonal principal es mayor que la suma de los elementos de la diagonal secundaria.

# %%
mat <- matrix(c(1,2,3,4,5,6,7,8,9), nrow=3)
mat

# %% [markdown]
# 4. Considear el dataframe $\tt stocks$ que contiene información diaria sobre el precio de cierre de una acción y su volumen. Las columnas son: fecha, precio, y volumen. Verificar si en los días que el precio de cierre fue mayor que el promedio general, el volumen también fue mayor que el volumen promedio general.

# %%
stocks = data.frame(fecha = c("2023-01-01", "2023-01-02", "2023-01-03"),
                    precio = c(100, 105, 103),
                    volumen = c(1000, 1100, 950))
stocks

# %% [markdown]
# <div style="background-color:#F7DC6F"><b>Resolución Ejercicio 06</b></div>

# %% [markdown]
# <div style="background-color:#5DADE2"><b>Apartado 1</b></div>

# %% [markdown]
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>
